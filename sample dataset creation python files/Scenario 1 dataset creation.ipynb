# %% [markdown]
# This file is to show a sample of the base code used for creating the scenarios 1-3 train and test datasets. The following code uses the scapy package to import and create pcap files. A reference to the scapy guide that was used is located at:
#
# https://scapy.readthedocs.io/en/latest/

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# using scapy to import and construct new pcap files

# %%
##The following guide was used as reference for the following code: https://scapy.readthedocs.io/en/latest/

pip install scapy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import pandas as pd
import numpy as np
from scapy.all import *
from scapy.layers.http import *

# %% [markdown]
# # pcap creation:

# %%
Week1_Wednesday_Neptune = PcapReader('/content/drive/MyDrive/ECE 697 Project/1. datasets/DARPA 1998/DARPA98_Attacks/Attacks_Truncated/DARPA98_Training_Week1_Wednesday_Neptune_Attack.pcap')
Week1_Wednesday_Smurf = PcapReader('/content/drive/MyDrive/ECE 697 Project/1. datasets/DARPA 1998/DARPA98_Attacks/Attacks_Truncated/DARPA98_Training_Week1_Wednesday_Smurf_Attack.pcap')
Week1_Thursday_Pod = PcapReader('/content/drive/MyDrive/ECE 697 Project/1. datasets/DARPA 1998/DARPA98_Attacks/Attacks_Truncated/DARPA98_Training_Week1_Thursday_Pod_Attack.pcap')
Week1_Friday_Teardrop = PcapReader('/content/drive/MyDrive/ECE 697 Project/1. datasets/DARPA 1998/DARPA98_Attacks/Attacks_Truncated/DARPA98_Training_Week1_Friday_Teardrop_Attack.pcap')
Week2_Wednesday_Land = PcapReader('/content/drive/MyDrive/ECE 697 Project/1. datasets/DARPA 1998/DARPA98_Attacks/Attacks_Truncated/DARPA98_Training_Week2_Wednesday_Land_Attack.pcap')
Week2_Friday_Back = PcapReader('/content/drive/MyDrive/ECE 697 Project/1. datasets/DARPA 1998/DARPA98_Attacks/Attacks_Truncated/DARPA98_Training_Week2_Friday_Back_Attack.pcap')
Week2_Friday_Syslog = PcapReader('/content/drive/MyDrive/ECE 697 Project/1. datasets/DARPA 1998/DARPA98_Attacks/Attacks_Truncated/DARPA98_Training_Week2_Friday_Syslog_Attack.pcap')
Week3_Wednesday_Smurf = PcapReader('/content/drive/MyDrive/ECE 697 Project/1. datasets/DARPA 1998/DARPA98_Attacks/Attacks_Truncated/DARPA98_Training_Week3_Wednesday_Smurf_Attack.pcap')
Week3_Friday_Land = PcapReader('/content/drive/MyDrive/ECE 697 Project/1. datasets/DARPA 1998/DARPA98_Attacks/Attacks_Truncated/DARPA98_Training_Week3_Friday_Land_Attack.pcap')
Week4_Tuesday_Pod = PcapReader('/content/drive/MyDrive/ECE 697 Project/1. datasets/DARPA 1998/DARPA98_Attacks/Attacks_Truncated/DARPA98_Training_Week4_Tuesday_Pod_Attack.pcap')
Week4_Tuesday_Teardrop = PcapReader('/content/drive/MyDrive/ECE 697 Project/1. datasets/DARPA 1998/DARPA98_Attacks/Attacks_Truncated/DARPA98_Training_Week4_Tuesday_Teardrop_Attack.pcap')
Week4_Thursday_Syslog = PcapReader('/content/drive/MyDrive/ECE 697 Project/1. datasets/DARPA 1998/DARPA98_Attacks/Attacks_Truncated/DARPA98_Training_Week4_Thursday_Syslog_Attack.pcap')
Week5_Wednesday_Syslog = PcapReader('/content/drive/MyDrive/ECE 697 Project/1. datasets/DARPA 1998/DARPA98_Attacks/Attacks_Truncated/DARPA98_Training_Week5_Wednesday_Syslog_Attack.pcap')
Week5_Thursday_Land = PcapReader('/content/drive/MyDrive/ECE 697 Project/1. datasets/DARPA 1998/DARPA98_Attacks/Attacks_Truncated/DARPA98_Training_Week5_Thursday_Land_Attack.pcap')
Week6_Monday_Neptune = PcapReader('/content/drive/MyDrive/ECE 697 Project/1. datasets/DARPA 1998/DARPA98_Attacks/Attacks_Truncated/DARPA98_Training_Week6_Monday_Neptune_Attack.pcap')
Week6_Wednesday_Back = PcapReader('/content/drive/MyDrive/ECE 697 Project/1. datasets/DARPA 1998/DARPA98_Attacks/Attacks_Truncated/DARPA98_Training_Week6_Wednesday_Back_Attack.pcap')
Week6_Thursday_Pod1 = PcapReader('/content/drive/MyDrive/ECE 697 Project/1. datasets/DARPA 1998/DARPA98_Attacks/Attacks_Truncated/DARPA98_Training_Week6_Thursday_Pod1_Attack.pcap')


DARPA99_benign = rdpcap('/content/drive/MyDrive/ECE 697 Project/1. datasets/DARPA 1999/Training/Week 1/Monday/outside.tcpdump_short.pcap')

# %%
#The following guide was used as reference for the following code: https://scapy.readthedocs.io/en/latest/

#creating the scenario 1 training data pcap file:

wrpcap('Scenario 1 training data.pcap', DARPA99_benign[50000:53000], append=True)
wrpcap('Scenario 1 training data.pcap', Week1_Wednesday_Neptune, append=True)

wrpcap('Scenario 1 training data.pcap', DARPA99_benign[53000:56000], append=True)
wrpcap('Scenario 1 training data.pcap', Week1_Wednesday_Smurf, append=True)

wrpcap('Scenario 1 training data.pcap', DARPA99_benign[56000:59000], append=True)
wrpcap('Scenario 1 training data.pcap', Week1_Thursday_Pod, append=True)

wrpcap('Scenario 1 training data.pcap', DARPA99_benign[59000:62000], append=True)
wrpcap('Scenario 1 training data.pcap', Week1_Friday_Teardrop, append=True)

wrpcap('Scenario 1 training data.pcap', DARPA99_benign[62000:65000], append=True)
wrpcap('Scenario 1 training data.pcap', Week2_Wednesday_Land, append=True)

wrpcap('Scenario 1 training data.pcap', DARPA99_benign[65000:68000], append=True)
wrpcap('Scenario 1 training data.pcap', Week2_Friday_Back, append=True)

wrpcap('Scenario 1 training data.pcap', DARPA99_benign[68000:71000], append=True)
wrpcap('Scenario 1 training data.pcap', Week2_Friday_Syslog, append=True)

wrpcap('Scenario 1 training data.pcap', DARPA99_benign[71000:74000], append=True)
wrpcap('Scenario 1 training data.pcap', Week3_Wednesday_Smurf, append=True)

wrpcap('Scenario 1 training data.pcap', DARPA99_benign[74000:77000], append=True)
wrpcap('Scenario 1 training data.pcap', Week3_Friday_Land, append=True)

wrpcap('Scenario 1 training data.pcap', DARPA99_benign[77000:80000], append=True)
wrpcap('Scenario 1 training data.pcap', Week4_Tuesday_Pod, append=True)

wrpcap('Scenario 1 training data.pcap', DARPA99_benign[80000:83000], append=True)
wrpcap('Scenario 1 training data.pcap', Week4_Tuesday_Teardrop, append=True)

wrpcap('Scenario 1 training data.pcap', DARPA99_benign[83000:86000], append=True)
wrpcap('Scenario 1 training data.pcap', Week4_Thursday_Syslog, append=True)

wrpcap('Scenario 1 training data.pcap', DARPA99_benign[86000:89000], append=True)
wrpcap('Scenario 1 training data.pcap', Week5_Wednesday_Syslog, append=True)

wrpcap('Scenario 1 training data.pcap', DARPA99_benign[89000:92000], append=True)
wrpcap('Scenario 1 training data.pcap', Week5_Thursday_Land, append=True)

wrpcap('Scenario 1 training data.pcap', DARPA99_benign[92000:95000], append=True)
wrpcap('Scenario 1 training data.pcap', Week6_Monday_Neptune, append=True)

wrpcap('Scenario 1 training data.pcap', DARPA99_benign[95000:98000], append=True)
wrpcap('Scenario 1 training data.pcap', Week6_Wednesday_Back, append=True)

wrpcap('Scenario 1 training data.pcap', DARPA99_benign[98000:101000], append=True)
wrpcap('Scenario 1 training data.pcap', Week6_Thursday_Pod1, append=True)

# %% [markdown]
# # label creation:

# %%
Week1_Wednesday_Neptune_labels = pd.read_csv('/content/drive/MyDrive/ECE 697 Project/1. datasets/DARPA 1998/DARPA98_Attacks/Labels_Truncated/DARPA98_Training_Week1_Wednesday_Neptune_Attack_Labels.csv',header=None).to_numpy()
Week1_Wednesday_Smurf_labels = pd.read_csv('/content/drive/MyDrive/ECE 697 Project/1. datasets/DARPA 1998/DARPA98_Attacks/Labels_Truncated/DARPA98_Training_Week1_Wednesday_Smurf_Attack_Labels.csv',header=None).to_numpy()
Week1_Thursday_Pod_labels = pd.read_csv('/content/drive/MyDrive/ECE 697 Project/1. datasets/DARPA 1998/DARPA98_Attacks/Labels_Truncated/DARPA98_Training_Week1_Thursday_Pod_Attack_Labels.csv',header=None).to_numpy()
Week1_Friday_Teardrop_labels = pd.read_csv('/content/drive/MyDrive/ECE 697 Project/1. datasets/DARPA 1998/DARPA98_Attacks/Labels_Truncated/DARPA98_Training_Week1_Friday_Teardrop_Attack_Labels.csv',header=None).to_numpy()
Week2_Wednesday_Land_labels = pd.read_csv('/content/drive/MyDrive/ECE 697 Project/1. datasets/DARPA 1998/DARPA98_Attacks/Labels_Truncated/DARPA98_Training_Week2_Wednesday_Land_Attack_Labels.csv',header=None).to_numpy()
Week2_Friday_Back_labels = pd.read_csv('/content/drive/MyDrive/ECE 697 Project/1. datasets/DARPA 1998/DARPA98_Attacks/Labels_Truncated/DARPA98_Training_Week2_Friday_Back_Attack_Labels.csv',header=None).to_numpy()
Week2_Friday_Syslog_labels = pd.read_csv('/content/drive/MyDrive/ECE 697 Project/1. datasets/DARPA 1998/DARPA98_Attacks/Labels_Truncated/DARPA98_Training_Week2_Friday_Syslog_Attack_Labels.csv',header=None).to_numpy()
Week3_Wednesday_Smurf_labels = pd.read_csv('/content/drive/MyDrive/ECE 697 Project/1. datasets/DARPA 1998/DARPA98_Attacks/Labels_Truncated/DARPA98_Training_Week3_Wednesday_Smurf_Attack_Labels.csv',header=None).to_numpy()
Week3_Friday_Land_labels = pd.read_csv('/content/drive/MyDrive/ECE 697 Project/1. datasets/DARPA 1998/DARPA98_Attacks/Labels_Truncated/DARPA98_Training_Week3_Friday_Land_Attack_Labels.csv',header=None).to_numpy()
Week4_Tuesday_Pod_labels = pd.read_csv('/content/drive/MyDrive/ECE 697 Project/1. datasets/DARPA 1998/DARPA98_Attacks/Labels_Truncated/DARPA98_Training_Week4_Tuesday_Pod_Attack_Labels.csv',header=None).to_numpy()
Week4_Tuesday_Teardrop_labels = pd.read_csv('/content/drive/MyDrive/ECE 697 Project/1. datasets/DARPA 1998/DARPA98_Attacks/Labels_Truncated/DARPA98_Training_Week4_Tuesday_Teardrop_Attack_Labels.csv',header=None).to_numpy()
Week4_Thursday_Syslog_labels = pd.read_csv('/content/drive/MyDrive/ECE 697 Project/1. datasets/DARPA 1998/DARPA98_Attacks/Labels_Truncated/DARPA98_Training_Week4_Thursday_Syslog_Attack_Labels.csv',header=None).to_numpy()
Week5_Wednesday_Syslog_labels = pd.read_csv('/content/drive/MyDrive/ECE 697 Project/1. datasets/DARPA 1998/DARPA98_Attacks/Labels_Truncated/DARPA98_Training_Week5_Wednesday_Syslog_Attack_Labels.csv',header=None).to_numpy()
Week5_Thursday_Land_labels = pd.read_csv('/content/drive/MyDrive/ECE 697 Project/1. datasets/DARPA 1998/DARPA98_Attacks/Labels_Truncated/DARPA98_Training_Week5_Thursday_Land_Attack_Labels.csv',header=None).to_numpy()
Week6_Monday_Neptune_labels = pd.read_csv('/content/drive/MyDrive/ECE 697 Project/1. datasets/DARPA 1998/DARPA98_Attacks/Labels_Truncated/DARPA98_Training_Week6_Monday_Neptune_Attack_Labels.csv',header=None).to_numpy()
Week6_Wednesday_Back_labels = pd.read_csv('/content/drive/MyDrive/ECE 697 Project/1. datasets/DARPA 1998/DARPA98_Attacks/Labels_Truncated/DARPA98_Training_Week6_Wednesday_Back_Attack_Labels.csv',header=None).to_numpy()
Week6_Thursday_Pod1_labels = pd.read_csv('/content/drive/MyDrive/ECE 697 Project/1. datasets/DARPA 1998/DARPA98_Attacks/Labels_Truncated/DARPA98_Training_Week6_Thursday_Pod1_Attack_Labels.csv',header=None).to_numpy()

DARPA99_benign_labels = pd.read_csv('/content/drive/MyDrive/ECE 697 Project/1. datasets/DARPA 1999/Training/Week 1/Monday/DARPA99_training_week1_Monday_labels.csv',header=None).to_numpy()

# %%
#creating the scenario 1 labels that go with the pcap file that was just created above

label_list = np.vstack((DARPA99_benign_labels[50000:53000],Week1_Wednesday_Neptune_labels))

label_list = np.vstack((label_list, DARPA99_benign_labels[53000:56000]))
label_list = np.vstack((label_list, Week1_Wednesday_Smurf_labels))

label_list = np.vstack((label_list, DARPA99_benign_labels[56000:59000]))
label_list = np.vstack((label_list, Week1_Thursday_Pod_labels))

label_list = np.vstack((label_list, DARPA99_benign_labels[59000:62000]))
label_list = np.vstack((label_list, Week1_Friday_Teardrop_labels))

label_list = np.vstack((label_list, DARPA99_benign_labels[62000:65000]))
label_list = np.vstack((label_list, Week2_Wednesday_Land_labels))

label_list = np.vstack((label_list, DARPA99_benign_labels[65000:68000]))
label_list = np.vstack((label_list, Week2_Friday_Back_labels))

label_list = np.vstack((label_list, DARPA99_benign_labels[68000:71000]))
label_list = np.vstack((label_list, Week2_Friday_Syslog_labels))

label_list = np.vstack((label_list, DARPA99_benign_labels[71000:74000]))
label_list = np.vstack((label_list, Week3_Wednesday_Smurf_labels))

label_list = np.vstack((label_list, DARPA99_benign_labels[74000:77000]))
label_list = np.vstack((label_list, Week3_Friday_Land_labels))

label_list = np.vstack((label_list, DARPA99_benign_labels[77000:80000]))
label_list = np.vstack((label_list, Week4_Tuesday_Pod_labels))

label_list = np.vstack((label_list, DARPA99_benign_labels[80000:83000]))
label_list = np.vstack((label_list, Week4_Tuesday_Teardrop_labels))

label_list = np.vstack((label_list, DARPA99_benign_labels[83000:86000]))
label_list = np.vstack((label_list, Week4_Thursday_Syslog_labels))

label_list = np.vstack((label_list, DARPA99_benign_labels[86000:89000]))
label_list = np.vstack((label_list, Week5_Wednesday_Syslog_labels))

label_list = np.vstack((label_list, DARPA99_benign_labels[89000:92000]))
label_list = np.vstack((label_list, Week5_Thursday_Land_labels))

label_list = np.vstack((label_list, DARPA99_benign_labels[92000:95000]))
label_list = np.vstack((label_list, Week6_Monday_Neptune_labels))

label_list = np.vstack((label_list, DARPA99_benign_labels[95000:98000]))
label_list = np.vstack((label_list, Week6_Wednesday_Back_labels))

label_list = np.vstack((label_list, DARPA99_benign_labels[98000:101000]))
label_list = np.vstack((label_list, Week6_Thursday_Pod1_labels))

# %%
np.shape(label_list)
# Out:
# (73793, 1)

# %%
pd.DataFrame(label_list).to_csv('Scenario 1 training data labels.csv', header=None, index=False)
